# %% [markdown]
# 作業2：請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
# 由NHL冰球統計資料分析來增加觀看運動的樂趣
#
# 評估個人行為對比賽結果的貢獻與程度
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 提供者:Martin Ellis，以過去6年中NHL中每場比賽測量的所有官方指標
#
# 3. 蒐集而來的資料型態為何
#
# CSV檔，裡面包括了許多種數據，如球員統計數據
#
# 包括個人比賽的細節，如射門、進球和暫停，包括了日期和時間以及x，y坐標
#
# 4. 這組資料想解決的問題如何評估
#
# 與其他運動相比，曲棍球的統計數據仍處於起步階段
#
# 在此最佳狀況只能有62％的機率預測誰是勝利者
#
# 故資料提供者希望能夠提高預測機率準確性

# %% [markdown]
# 作業3：想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 找出載客熱點區域在哪裡，如何在最短時間內發送給司機，快速完成媒合派車任務
#
# a.由司機的接送點記錄分析出每個時段最佳載客熱點，提供給目前空車的司機
#
# b.由APP客戶叫車指派最接近的空車司機
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 資料由司機在路上載客而來，設定一套APP，讓司機按下已載客與結束任務
#
# 3. 蒐集而來的資料型態為何
#
# 資料型態：時間、地點、人數、男或女
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# 這套APP會出現的問題在於司機要按下已載客與結束任務按鈕
#
# 但時間、地點、人數、男或女的記錄將會不容易記錄
#
# 若是在客人下車後再記錄，如果剛好又有客人，很大的機率會失去先前的一筆記錄
#
# 但如果能用車內的Camera記錄，自動影像分析即可解決司機記錄不便的問題
#
# 假設APP結合Camera可解決記錄上的不便，只要客人上車後，即可往後台記錄找出載客熱點與調派司機
